# %% [markdown]
# ***Note: Google Colab has been used to run the the file***

# %% [markdown]
# # WHY FAKE NEWS IS A PROBLEM?
# **Fake news refers to misinformation, disinformation or mal-information which is spread through word of mouth and traditional media and more recently through digital forms of communication such as edited videos, memes, unverified advertisements and social media propagated rumours.Fake news spread through social media has become a serious problem, with the potential of it resulting in mob violence, suicides etc as a result of misinformation circulated on social media.**
# ![image.png](data:image/png;base64,...)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ## STEP 1: Import necessary libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from sklearn.preprocessing import LabelBinarizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud, STOPWORDS
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize, sent_tokenize
from bs4 import BeautifulSoup
import re
import string
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout
from keras.callbacks import ReduceLROnPlateau

# %% [markdown]
# ## STEP 2: Load the dataset
# - The dataset is stored in the Google Drive folder (news) with two files (True.csv & Fake.csv).
#
# #### **BRIEF DESCRIPTION OF DATASET**
# This dataset consists of about 40000 articles consisting of fake as well as real news. Our aim is train our model so that it can correctly predict whether a given piece of news is real or fake.The fake and real news data is given in two separate datasets with each dataset consisting around 20000 articles each.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
true = pd.read_csv("drive/MyDrive/True.csv")
false = pd.read_csv("drive/MyDrive/Fake.csv")

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
false.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %% [markdown]
# ## STEP 3: Combine the datasets

# %%
true['category'] = 1
false['category'] = 0
df = pd.concat([true, false])

# %%
df.isnull().sum()
# Out:
# title       0
# text        0
# subject     0
# date        0
# category    0
# dtype: int64

# %% [markdown]
# ## STEP 4: Clean the data

# %%
text = """
<p>Breaking News!!! Visit http://fake-news.com</p>
The government has announced a NEW policy, and people are sharing it on social media!!!

"""

# %%
text = BeautifulSoup(text, "html.parser").get_text()
text
# Out:
# '\nBreaking News!!! Visit http://fake-news.com\nThe government has announced a NEW policy, and people are sharing it on social media!!!\n\n'

# %%
text = re.sub(r'http\S+', '', text)
text
# Out:
# '\nBreaking News!!! Visit \nThe government has announced a NEW policy, and people are sharing it on social media!!!\n\n'

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def clean_text(text):
    text = BeautifulSoup(text, "html.parser").get_text()
    text = re.sub(r'http\S+', '', text)
    stop = set(stopwords.words('english'))
    punctuation = list(string.punctuation)
    stop.update(punctuation)
    final_text = []
    for word in text.split():
        if word.strip().lower() not in stop:
            final_text.append(word.strip())
    cleaned_text = " ".join(final_text)

    # Check if the cleaned text is empty
    if not cleaned_text:
        cleaned_text = "placeholder"  # Add a placeholder word

    return cleaned_text

df['clean_text'] = df['text'].apply(clean_text)
# Out:
# /tmp/ipython-input-3730861894.py:2: MarkupResemblesLocatorWarning: The input passed in on this line looks more like a URL than HTML or XML.
#
# If you meant to use Beautiful Soup to parse the web page found at a certain URL, then something has gone wrong. You should use an Python package like 'requests' to fetch the content behind the URL. Once you have the content as a string, you can feed that string into Beautiful Soup.
#
# However, if you want to parse some data that happens to look like a URL, then nothing has gone wrong: you are using Beautiful Soup correctly, and this warning is spurious and can be filtered. To make this warning go away, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import MarkupResemblesLocatorWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=MarkupResemblesLocatorWarning)
#
#   text = BeautifulSoup(text, "html.parser").get_text()

# %% [markdown]
# ## STEP 5: Word cloud for real and fake text

# %%
# Word cloud for real and fake text
def plot_wordcloud(category):
    wc = WordCloud(max_words=2000, width=1600, height=800, stopwords=STOPWORDS).generate(" ".join(df[df.category == category].clean_text))
    plt.imshow(wc, interpolation='bilinear')
    plt.show()

# Plot word cloud for real text
plot_wordcloud(1)

# Plot word cloud for fake text
plot_wordcloud(0)

# %% [markdown]
# ## STEP 6: Split the data into training and testing sets

# %%
x_train, x_test, y_train, y_test = train_test_split(df.clean_text, df.category, random_state=0)

# %% [markdown]
# ## STEP 7: Tokenizing text and padding sequences

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
max_features = 10000
maxlen = 300

tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(x_train)

# Train
tokenized_train = tokenizer.texts_to_sequences(x_train)
x_train = pad_sequences(tokenized_train, maxlen=maxlen)

# Test
tokenized_test = tokenizer.texts_to_sequences(x_test)
x_test = pad_sequences(tokenized_test, maxlen=maxlen)

# %%
tokenizer.word_index
# Out:
# {'said': 1,
#  'trump': 2,
#  'would': 3,
#  'president': 4,
#  'u': 5,
#  's': 6,
#  'people': 7,
#  '”': 8,
#  'one': 9,
#  'state': 10,
#  'also': 11,
#  'new': 12,
#  'reuters': 13,
#  'donald': 14,
#  'government': 15,
#  'house': 16,
#  'clinton': 17,
#  'states': 18,
#  'obama': 19,
#  'republican': 20,
#  'year': 21,
#  'could': 22,
#  'united': 23,
#  'told': 24,
#  'like': 25,
#  'white': 26,
#  'two': 27,
#  'campaign': 28,
#  'time': 29,
#  'election': 30,
#  'last': 31,
#  'news': 32,
#  'party': 33,
#  'first': 34,
#  'the': 35,
#  'washington': 36,
#  'even': 37,
#  'former': 38,
#  'country': 39,
#  'us': 40,
#  'years': 41,
#  'many': 42,
#  'hillary': 43,
#  'it': 44,
#  'american': 45,
#  'media': 46,
#  'security': 47,
#  'law': 48,
#  'say': 49,
#  'may': 50,
#  'made': 51,
#  'national': 52,
#  'political': 53,
#  'police': 54,
#  'get': 55,
#  'since': 56,
#  'right': 57,
#  'make': 58,
#  'court': 59,
#  'according': 60,
#  'going': 61,
#  'percent': 62,
#  'twitter': 63,
#  'republicans': 64,
#  'back': 65,
#  'presidential': 66,
#  'administration': 67,
#  'called': 68,
#  'russia': 69,
#  'via': 70,
#  'week': 71,
#  'bill': 72,
#  'democratic': 73,
#  'support': 74,
#  'america': 75,
#  'vote': 76,
#  'group': 77,
#  'know': 78,
#  'north': 79,
#  'senate': 80,
#  'including': 81,
#  'way': 82,
#  'think': 83,
#  'officials': 84,
#  'well': 85,
#  'office': 86,
#  'public': 87,
#  'take': 88,
#  'federal': 89,
#  'military': 90,
#  'foreign': 91,
#  'statement': 92,
#  'world': 93,
#  '000': 94,
#  'trump’s': 95,
#  'day': 96,
#  'million': 97,
#  'department': 98,
#  'saying': 99,
#  'want': 100,
#  '1': 101,
#  'see': 102,
#  'tax': 103,
#  'russian': 104,
#  'tuesday': 105,
#  'still': 106,
#  'says': 107,
#  'much': 108,
#  'another': 109,
#  '2016': 110,
#  'image': 111,
#  'part': 112,
#  'congress': 113,
#  'wednesday': 114,
#  'women': 115,
#  'work': 116,
#  'go': 117,
#  'in': 118,
#  'city': 119,
#  'friday': 120,
#  'minister': 121,
#  'war': 122,
#  'thursday': 123,
#  'asked': 124,
#  'policy': 125,
#  'three': 126,
#  'democrats': 127,
#  'video': 128,
#  'americans': 129,
#  'secretary': 130,
#  'long': 131,
#  'monday': 132,
#  'rights': 133,
#  'general': 134,
#  'china': 135,
#  'york': 136,
#  'black': 137,
#  'deal': 138,
#  'committee': 139,
#  'official': 140,
#  'left': 141,
#  'help': 142,
#  'next': 143,
#  'case': 144,
#  'whether': 145,
#  'need': 146,
#  'never': 147,
#  'show': 148,
#  'that': 149,
#  'featured': 150,
#  'around': 151,
#  'korea': 152,
#  'man': 153,
#  'senator': 154,
#  'leader': 155,
#  'members': 156,
#  'use': 157,
#  'order': 158,
#  'candidate': 159,
#  'month': 160,
#  'took': 161,
#  'com': 162,
#  'old': 163,
#  'end': 164,
#  'good': 165,
#  'report': 166,
#  'come': 167,
#  'every': 168,
#  'this': 169,
#  'fbi': 170,
#  'power': 171,
#  'meeting': 172,
#  'times': 173,
#  'intelligence': 174,
#  'far': 175,
#  'without': 176,
#  '2': 177,
#  'iran': 178,
#  'investigation': 179,
#  'used': 180,
#  'countries': 181,
#  'money': 182,
#  'really': 183,
#  'nuclear': 184,
#  'put': 185,
#  'justice': 186,
#  'anti': 187,
#  'information': 188,
#  'top': 189,
#  'change': 190,
#  'syria': 191,
#  'post': 192,
#  'attack': 193,
#  'reported': 194,
#  'business': 195,
#  'fact': 196,
#  'decision': 197,
#  'trade': 198,
#  'family': 199,
#  'voters': 200,
#  'however': 201,
#  'leaders': 202,
#  'story': 203,
#  'days': 204,
#  'south': 205,
#  'international': 206,
#  'already': 207,
#  'him': 208,
#  'several': 209,
#  'speech': 210,
#  'here': 211,
#  'interview': 212,
#  'plan': 213,
#  'groups': 214,
#  'high': 215,
#  'director': 216,
#  'place': 217,
#  'watch': 218,
#  'chief': 219,
#  'months': 220,
#  'conservative': 221,
#  '5': 222,
#  'immigration': 223,
#  '10': 224,
#  'muslim': 225,
#  'home': 226,
#  'something': 227,
#  'among': 228,
#  '3': 229,
#  'health': 230,
#  'pic': 231,
#  'agency': 232,
#  'program': 233,
#  'clear': 234,
#  'likely': 235,
#  'border': 236,
#  'call': 237,
#  'must': 238,
#  'john': 239,
#  'them': 240,
#  'children': 241,
#  'believe': 242,
#  'act': 243,
#  'social': 244,
#  'islamic': 245,
#  'move': 246,
#  'press': 247,
#  'issue': 248,
#  'fox': 249,
#  'al': 250,
#  'barack': 251,
#  'today': 252,
#  'free': 253,
#  'billion': 254,
#  'four': 255,
#  'later': 256,
#  'now': 257,
#  'sunday': 258,
#  'though': 259,
#  'might': 260,
#  'things': 261,
#  'based': 262,
#  'least': 263,
#  'supporters': 264,
#  'yet': 265,
#  'came': 266,
#  'making': 267,
#  'control': 268,
#  'nation': 269,
#  'recent': 270,
#  'number': 271,
#  'matter': 272,
#  'major': 273,
#  'seen': 274,
#  'sanders': 275,
#  'found': 276,
#  'got': 277,
#  'working': 278,
#  'member': 279,
#  'reporters': 280,
#  'defense': 281,
#  'n': 282,
#  'killed': 283,
#  'point': 284,
#  'earlier': 285,
#  'added': 286,
#  'trying': 287,
#  'great': 288,
#  'spokesman': 289,
#  'violence': 290,
#  'let': 291,
#  'a': 292,
#  'went': 293,
#  'eu': 294,
#  '8': 295,
#  'system': 296,
#  'known': 297,
#  'school': 298,
#  'actually': 299,
#  'and': 300,
#  'past': 301,
#  '4': 302,
#  'win': 303,
#  '2017': 304,
#  'set': 305,
#  'become': 306,
#  'so': 307,
#  'little': 308,
#  'thing': 309,
#  'economic': 310,
#  'real': 311,
#  'held': 312,
#  'march': 313,
#  'stop': 314,
#  'ever': 315,
#  'away': 316,
#  'legal': 317,
#  'look': 318,
#  'run': 319,
#  'cnn': 320,
#  'executive': 321,
#  'attacks': 322,
#  'democrat': 323,
#  'keep': 324,
#  'forces': 325,
#  'led': 326,
#  'give': 327,
#  'senior': 328,
#  'life': 329,
#  'big': 330,
#  'comment': 331,
#  'january': 332,
#  'european': 333,
#  'nothing': 334,
#  '20': 335,
#  'cruz': 336,
#  'majority': 337,
#  'following': 338,
#  'local': 339,
#  'july': 340,
#  '2015': 341,
#  'head': 342,
#  'human': 343,
#  'care': 344,
#  'prime': 345,
#  'wall': 346,
#  'taking': 347,
#  'union': 348,
#  'action': 349,
#  'governor': 350,
#  'force': 351,
#  'person': 352,
#  'second': 353,
#  'reports': 354,
#  'lawmakers': 355,
#  'issues': 356,
#  'night': 357,
#  'attorney': 358,
#  'community': 359,
#  'illegal': 360,
#  'talks': 361,
#  'face': 362,
#  'across': 363,
#  'expected': 364,
#  'up': 365,
#  'woman': 366,
#  'possible': 367,
#  'nominee': 368,
#  'men': 369,
#  'better': 370,
#  'gun': 371,
#  'pay': 372,
#  'job': 373,
#  'opposition': 374,
#  'source': 375,
#  'others': 376,
#  'companies': 377,
#  'continue': 378,
#  'sanctions': 379,
#  'given': 380,
#  'released': 381,
#  'wrote': 382,
#  'history': 383,
#  'team': 384,
#  'enough': 385,
#  'read': 386,
#  'nations': 387,
#  'taken': 388,
#  'done': 389,
#  'process': 390,
#  'company': 391,
#  'evidence': 392,
#  'legislation': 393,
#  'question': 394,
#  'course': 395,
#  'open': 396,
#  'full': 397,
#  'financial': 398,
#  'images': 399,
#  'five': 400,
#  'wants': 401,
#  'supreme': 402,
#  'judge': 403,
#  'response': 404,
#  'close': 405,
#  'air': 406,
#  'despite': 407,
#  'center': 408,
#  'realdonaldtrump': 409,
#  'refugees': 410,
#  'important': 411,
#  'university': 412,
#  'anyone': 413,
#  'mexico': 414,
#  'special': 415,
#  'on': 416,
#  'june': 417,
#  'iraq': 418,
#  'race': 419,
#  'ago': 420,
#  'private': 421,
#  'lot': 422,
#  'november': 423,
#  'out': 424,
#  'syrian': 425,
#  'mr': 426,
#  'using': 427,
#  'plans': 428,
#  'staff': 429,
#  'saturday': 430,
#  'hard': 431,
#  'gop': 432,
#  'comments': 433,
#  'fight': 434,
#  'budget': 435,
#  'anything': 436,
#  'ban': 437,
#  'death': 438,
#  'instead': 439,
#  'along': 440,
#  'debate': 441,
#  'region': 442,
#  'able': 443,
#  'less': 444,
#  'agreement': 445,
#  'efforts': 446,
#  '6': 447,
#  'conference': 448,
#  'crisis': 449,
#  'saudi': 450,
#  'facebook': 451,
#  'future': 452,
#  '30': 453,
#  'accused': 454,
#  'putin': 455,
#  'all': 456,
#  'you': 457,
#  'best': 458,
#  'early': 459,
#  'behind': 460,
#  'term': 461,
#  'lives': 462,
#  'email': 463,
#  'lead': 464,
#  'letter': 465,
#  'is': 466,
#  'find': 467,
#  '9': 468,
#  'within': 469,
#  '15': 470,
#  '7': 471,
#  'council': 472,
#  'getty': 473,
#  'someone': 474,
#  'role': 475,
#  'ryan': 476,
#  '2014': 477,
#  'current': 478,
#  '11': 479,
#  'due': 480,
#  'sure': 481,
#  'civil': 482,
#  'name': 483,
#  'comes': 484,
#  'line': 485,
#  '“i': 486,
#  'jobs': 487,
#  'citizens': 488,
#  'texas': 489,
#  'event': 490,
#  'service': 491,
#  'calling': 492,
#  'israel': 493,
#  'weeks': 494,
#  'getting': 495,
#  '“the': 496,
#  'middle': 497,
#  'coming': 498,
#  'britain': 499,
#  'visit': 500,
#  'muslims': 501,
#  'live': 502,
#  'weapons': 503,
#  'running': 504,
#  'rules': 505,
#  'announced': 506,
#  'coalition': 507,
#  'students': 508,
#  'young': 509,
#  'comey': 510,
#  'thousands': 511,
#  'six': 512,
#  'speaking': 513,
#  'sources': 514,
#  'votes': 515,
#  'there': 516,
#  'nearly': 517,
#  'congressional': 518,
#  'december': 519,
#  'chairman': 520,
#  'effort': 521,
#  'october': 522,
#  'late': 523,
#  'economy': 524,
#  'position': 525,
#  'elections': 526,
#  'sent': 527,
#  'front': 528,
#  'authorities': 529,
#  'talk': 530,
#  'rule': 531,
#  'paul': 532,
#  'april': 533,
#  'army': 534,
#  'capital': 535,
#  'whose': 536,
#  '12': 537,
#  'allow': 538,
#  'east': 539,
#  'began': 540,
#  'daily': 541,
#  'but': 542,
#  'problem': 543,
#  'claims': 544,
#  'august': 545,
#  'florida': 546,
#  'candidates': 547,
#  'street': 548,
#  'officers': 549,
#  'everyone': 550,
#  'backed': 551,
#  'showed': 552,
#  'organization': 553,
#  'september': 554,
#  'politics': 555,
#  'climate': 556,
#  'ties': 557,
#  'global': 558,
#  'threat': 559,
#  'outside': 560,
#  'workers': 561,
#  'wanted': 562,
#  'tell': 563,
#  'emails': 564,
#  'message': 565,
#  'immigrants': 566,
#  'hold': 567,
#  'leave': 568,
#  'criminal': 569,
#  'bad': 570,
#  'means': 571,
#  'turkey': 572,
#  'bush': 573,
#  'relations': 574,
#  'ruling': 575,
#  'obamacare': 576,
#  'together': 577,
#  'elected': 578,
#  'services': 579,
#  'stand': 580,
#  'words': 581,
#  'start': 582,
#  'again': 583,
#  'immediately': 584,
#  'needs': 585,
#  'racist': 586,
#  'february': 587,
#  'latest': 588,
#  'failed': 589,
#  'planned': 590,
#  'questions': 591,
#  'policies': 592,
#  'healthcare': 593,
#  'rather': 594,
#  'lost': 595,
#  'gave': 596,
#  'rally': 597,
#  'enforcement': 598,
#  'hope': 599,
#  'central': 600,
#  'oil': 601,
#  'different': 602,
#  'moscow': 603,
#  'access': 604,
#  'recently': 605,
#  'list': 606,
#  'pro': 607,
#  'reform': 608,
#  'voting': 609,
#  'release': 610,
#  'poll': 611,
#  'strong': 612,
#  'reason': 613,
#  'morning': 614,
#  'cut': 615,
#  'peace': 616,
#  'parliament': 617,
#  'fake': 618,
#  'received': 619,
#  'allies': 620,
#  'representatives': 621,
#  'spending': 622,
#  'funding': 623,
#  'thought': 624,
#  'almost': 625,
#  'involved': 626,
#  'try': 627,
#  'liberal': 628,
#  'missile': 629,
#  'near': 630,
#  'idea': 631,
#  'conservatives': 632,
#  'large': 633,
#  'germany': 634,
#  'tried': 635,
#  'laws': 636,
#  '100': 637,
#  'to': 638,
#  'cannot': 639,
#  'hate': 640,
#  'd': 641,
#  'millions': 642,
#  'more': 643,
#  'vice': 644,
#  'tv': 645,
#  'ministry': 646,
#  'charges': 647,
#  'non': 648,
#  'decided': 649,
#  'ahead': 650,
#  'century': 651,
#  'europe': 652,
#  'allowed': 653,
#  'happened': 654,
#  'side': 655,
#  'provide': 656,
#  'agencies': 657,
#  'george': 658,
#  'bring': 659,
#  'often': 660,
#  'host': 661,
#  'makes': 662,
#  'concerns': 663,
#  'small': 664,
#  'level': 665,
#  'fire': 666,
#  'officer': 667,
#  'parties': 668,
#  'protect': 669,
#  'looking': 670,
#  'talking': 671,
#  'met': 672,
#  'although': 673,
#  'western': 674,
#  'situation': 675,
#  'kind': 676,
#  'sexual': 677,
#  'entire': 678,
#  'always': 679,
#  'presidency': 680,
#  'area': 681,
#  'movement': 682,
#  'shot': 683,
#  'district': 684,
#  'key': 685,
#  'chinese': 686,
#  'denied': 687,
#  'county': 688,
#  'decades': 689,
#  'bank': 690,
#  'j': 691,
#  'california': 692,
#  'meet': 693,
#  'crime': 694,
#  'west': 695,
#  'needed': 696,
#  'calls': 697,
#  'fired': 698,
#  'everything': 699,
#  'hours': 700,
#  '2012': 701,
#  'water': 702,
#  'room': 703,
#  'tweet': 704,
#  'agreed': 705,
#  'freedom': 706,
#  'british': 707,
#  'market': 708,
#  '25': 709,
#  'allegations': 710,
#  'especially': 711,
#  'nomination': 712,
#  '“we': 713,
#  'wife': 714,
#  'request': 715,
#  'energy': 716,
#  'return': 717,
#  'true': 718,
#  'either': 719,
#  'james': 720,
#  'industry': 721,
#  'seems': 722,
#  'data': 723,
#  'terrorist': 724,
#  'include': 725,
#  'for': 726,
#  'protesters': 727,
#  'shooting': 728,
#  'terrorism': 729,
#  'voted': 730,
#  'half': 731,
#  'personal': 732,
#  'interest': 733,
#  'third': 734,
#  'fighting': 735,
#  'actions': 736,
#  'short': 737,
#  'hit': 738,
#  'representative': 739,
#  'me': 740,
#  'step': 741,
#  'myanmar': 742,
#  'documents': 743,
#  'foundation': 744,
#  'clearly': 745,
#  'son': 746,
#  'wrong': 747,
#  'forward': 748,
#  'insurance': 749,
#  'continued': 750,
#  'korean': 751,
#  'confirmed': 752,
#  'elect': 753,
#  'adding': 754,
#  'arrested': 755,
#  'polls': 756,
#  'hearing': 757,
#  'building': 758,
#  'passed': 759,
#  'worked': 760,
#  'travel': 761,
#  'paid': 762,
#  'claim': 763,
#  'shows': 764,
#  'address': 765,
#  'alleged': 766,
#  'independence': 767,
#  'potential': 768,
#  'commission': 769,
#  'claimed': 770,
#  'mean': 771,
#  'serious': 772,
#  'cases': 773,
#  '50': 774,
#  'spoke': 775,
#  'low': 776,
#  'leading': 777,
#  'biggest': 778,
#  'record': 779,
#  'hand': 780,
#  'no': 781,
#  'appeared': 782,
#  'board': 783,
#  'primary': 784,
#  'posted': 785,
#  'nov': 786,
#  'cost': 787,
#  'soon': 788,
#  'bernie': 789,
#  'feel': 790,
#  'truth': 791,
#  'michael': 792,
#  'probably': 793,
#  'turned': 794,
#  'religious': 795,
#  'main': 796,
#  'adviser': 797,
#  'largest': 798,
#  'review': 799,
#  'love': 800,
#  'issued': 801,
#  'brought': 802,
#  '2013': 803,
#  'tillerson': 804,
#  'toward': 805,
#  'page': 806,
#  'network': 807,
#  'protest': 808,
#  'pressure': 809,
#  'not': 810,
#  'david': 811,
#  'pass': 812,
#  'father': 813,
#  'turn': 814,
#  'mike': 815,
#  'points': 816,
#  'victory': 817,
#  'dollars': 818,
#  'cia': 819,
#  'declined': 820,
#  'co': 821,
#  'african': 822,
#  'taxes': 823,
#  'single': 824,
#  'article': 825,
#  'agenda': 826,
#  'simply': 827,
#  'families': 828,
#  'included': 829,
#  'college': 830,
#  'website': 831,
#  'related': 832,
#  'became': 833,
#  '13': 834,
#  'flynn': 835,
#  'remarks': 836,
#  'result': 837,
#  'armed': 838,
#  'leadership': 839,
#  'food': 840,
#  'signed': 841,
#  'described': 842,
#  't': 843,
#  'london': 844,
#  'mark': 845,
#  'started': 846,
#  'deputy': 847,
#  'details': 848,
#  '24': 849,
#  'influence': 850,
#  'spent': 851,
#  'final': 852,
#  'previously': 853,
#  'account': 854,
#  'i': 855,
#  'guy': 856,
#  'conflict': 857,
#  'view': 858,
#  'lawyer': 859,
#  'isis': 860,
#  'town': 861,
#  'seeking': 862,
#  'sign': 863,
#  '18': 864,
#  'down': 865,
#  'raised': 866,
#  'attempt': 867,
#  'longer': 868,
#  'child': 869,
#  'sessions': 870,
#  'class': 871,
#  'pence': 872,
#  'reality': 873,
#  'fund': 874,
#  'friends': 875,
#  'then': 876,
#  'giving': 877,
#  'protests': 878,
#  'fear': 879,
#  'popular': 880,
#  'at': 881,
#  'seven': 882,
#  'relationship': 883,
#  'wing': 884,
#  'income': 885,
#  'secret': 886,
#  'pretty': 887,
#  'arabia': 888,
#  'incident': 889,
#  'as': 890,
#  'hundreds': 891,
#  'constitution': 892,
#  'else': 893,
#  'convention': 894,
#  'example': 895,
#  'speak': 896,
#  'created': 897,
#  'merkel': 898,
#  'education': 899,
#  'ted': 900,
#  'saw': 901,
#  'areas': 902,
#  'mayor': 903,
#  'aid': 904,
#  'forced': 905,
#  'violent': 906,
#  'crowd': 907,
#  'heard': 908,
#  '16': 909,
#  '14': 910,
#  'regional': 911,
#  'san': 912,
#  'repeatedly': 913,
#  'proposed': 914,
#  'base': 915,
#  'troops': 916,
#  'currently': 917,
#  'independent': 918,
#  'lower': 919,
#  'wire': 920,
#  'remain': 921,
#  'do': 922,
#  'total': 923,
#  'similar': 924,
#  '21st': 925,
#  'militants': 926,
#  'push': 927,
#  'phone': 928,
#  'german': 929,
#  'ask': 930,
#  'respond': 931,
#  'below': 932,
#  'helped': 933,
#  'photo': 934,
#  'criticized': 935,
#  '17': 936,
#  'corruption': 937,
#  'hands': 938,
#  'her': 939,
#  'increase': 940,
#  'programs': 941,
#  'debt': 942,
#  'flag': 943,
#  'abortion': 944,
#  'r': 945,
#  'self': 946,
#  'tweeted': 947,
#  'carolina': 948,
#  'warned': 949,
#  'whole': 950,
#  'changes': 951,
#  'firm': 952,
#  'happen': 953,
#  'voter': 954,
#  'risk': 955,
#  'build': 956,
#  'victims': 957,
#  'mass': 958,
#  'stay': 959,
#  'criticism': 960,
#  'robert': 961,
#  'mccain': 962,
#  'employees': 963,
#  'apparently': 964,
#  'rubio': 965,
#  'rate': 966,
#  'kurdish': 967,
#  'northern': 968,
#  'ambassador': 969,
#  'nato': 970,
#  'mainstream': 971,
#  'speaker': 972,
#  'goes': 973,
#  'experts': 974,
#  'cause': 975,
#  'star': 976,
#  'funds': 977,
#  'published': 978,
#  'johnson': 979,
#  'breitbart': 980,
#  'refugee': 981,
#  'telling': 982,
#  'living': 983,
#  'eight': 984,
#  'beijing': 985,
#  'operations': 986,
#  'discuss': 987,
#  'christian': 988,
#  'moore': 989,
#  'understand': 990,
#  'safe': 991,
#  'king': 992,
#  'ground': 993,
#  'opinion': 994,
#  'medical': 995,
#  'inside': 996,
#  'television': 997,
#  'brexit': 998,
#  'powerful': 999,
#  'proposal': 1000,
#  ...}

# %%
# max_features = 10000
# maxlen = 300
# tokenizer = text.Tokenizer(num_words=max_features)
# tokenizer.fit_on_texts(x_train)
# tokenized_train = tokenizer.texts_to_sequences(x_train)
# x_train = sequence.pad_sequences(tokenized_train, maxlen=maxlen)
# tokenized_test = tokenizer.texts_to_sequences(x_test)
# x_test = sequence.pad_sequences(tokenized_test, maxlen=maxlen)

# %%
[o for o in open("drive/MyDrive/glove.twitter.27B.100d.txt", encoding='utf-8')][:5]
# Out:
# ['<user> 0.63006 0.65177 0.25545 0.018593 0.043094 0.047194 0.23218 0.11613 0.17371 0.40487 0.022524 -0.076731 -2.2911 0.094127 0.43293 0.041801 0.063175 -0.64486 -0.43657 0.024114 -0.082989 0.21686 -0.13462 -0.22336 0.39436 -2.1724 -0.39544 0.16536 0.39438 -0.35182 -0.14996 0.10502 -0.45937 0.27729 0.8924 -0.042313 -0.009345 0.55017 0.095521 0.070504 -1.1781 0.013723 0.17742 0.74142 0.17716 0.038468 -0.31684 0.08941 0.20557 -0.34328 -0.64303 -0.878 -0.16293 -0.055925 0.33898 0.60664 -0.2774 0.33626 0.21603 -0.11051 0.0058673 -0.64757 -0.068222 -0.77414 0.13911 -0.15851 -0.61885 -0.10192 -0.47 0.19787 0.42175 -0.18458 0.080581 -0.22545 -0.065129 -0.15328 0.087726 -0.18817 -0.08371 0.21779 0.97899 0.1092 0.022705 -0.078234 0.15595 0.083105 -0.6824 0.57469 -0.19942 0.50566 -0.18277 0.37721 -0.12514 -0.42821 -0.81075 -0.39326 -0.17386 0.55096 0.64706 -0.6093\n',
#  '. 0.18205 -0.048483 0.23966 0.32099 -0.27002 0.70431 -0.21257 0.235 0.090142 0.82141 0.37843 -0.56382 -2.4447 0.16827 0.24685 0.28649 0.062312 0.067508 -0.58459 -0.45414 -0.22158 0.17423 -0.35558 0.14485 0.49089 -1.7426 -0.54306 -0.51937 0.94795 -0.41739 -0.55238 -0.057398 -0.52663 0.62976 0.097275 0.20637 0.46261 0.089462 0.016019 -0.53854 -1.2043 0.080287 -0.65351 0.044617 0.79527 0.044508 0.53367 0.27444 -0.32461 -0.053683 -0.79304 0.11 0.39762 -0.044155 0.21701 0.27977 -0.25773 0.25085 0.39711 0.32318 0.10245 -0.030471 0.34113 0.17971 0.44436 0.054915 0.22461 -0.80843 -0.11052 0.42366 0.61091 0.55024 0.21958 -0.3029 0.14545 -0.46701 -0.23945 0.035106 -0.50933 -0.12392 0.24526 0.14758 -0.30313 -0.53052 0.80632 0.34566 -0.24541 0.71479 -0.15985 0.40129 -0.10851 -0.61427 -0.0035577 0.037739 -0.33055 -0.094383 0.38617 -0.3358 0.18884 -0.40786\n',
#  ': 1.0674 0.45716 0.51463 0.26679 0.19921 -0.072329 0.078455 0.19458 0.42281 0.1928 0.34424 -0.41104 -1.8649 -0.14081 0.23753 0.023077 -0.1115 -0.087478 -0.16193 -0.61093 -0.31741 -0.33686 -0.10769 0.46179 0.17931 -1.6432 -0.20659 0.34077 0.38932 -0.016806 -0.34337 -0.60921 -1.019 0.26511 0.85287 0.28141 -0.012736 0.41456 0.068343 -0.087932 -1.483 -0.072203 0.19278 0.64113 0.074135 -0.36254 -0.24202 -0.12651 0.19001 -0.4018 -0.92765 -0.33716 -0.31579 -0.090995 0.68764 0.35058 -0.12254 0.053486 0.24523 -0.0028901 -0.77917 0.19829 -0.19521 -1.2721 0.71733 -0.73878 -0.16419 -0.31932 0.051843 -0.08174 0.20602 -0.28411 0.4526 -0.47428 -0.40245 -0.6144 -0.056346 -0.53072 0.39851 -7.2866e-05 0.70299 -0.072685 0.45967 0.3748 0.052649 0.1852 -0.61182 1.1638 -0.26429 -0.15449 -0.48257 -0.060027 -0.36757 -0.055639 -0.14887 -0.33543 0.22757 0.13974 0.76487 -0.17314\n',
#  'rt 0.6047 0.89542 0.27923 0.033489 0.15873 0.18522 0.30722 0.47445 0.44484 0.7045 0.39528 -0.19818 -2.3884 0.095433 0.10782 0.26263 0.36582 -0.6385 -0.22938 -0.34722 0.10977 0.37367 -0.068053 -0.39421 0.43471 -2.1794 -0.47111 0.087237 0.57989 -0.020883 -0.0695 0.25771 -0.5019 0.41154 1.2178 0.47976 -0.31574 0.52983 0.041575 0.44973 -1.5363 -0.096062 -0.27531 0.52771 0.028587 0.047935 -0.5973 -0.051772 0.11377 -0.4049 -0.54857 -0.65916 -0.38132 -0.39519 0.42961 0.74531 -0.50838 0.40392 0.62699 -0.24798 -0.25386 0.21867 -0.072132 -0.51783 -0.054186 -0.66391 -0.58224 0.060621 -0.54001 0.72242 0.13349 -0.070261 -0.059061 -0.035474 -0.53649 -0.3755 0.11234 -0.3409 -0.13406 0.0078872 0.81973 -0.075774 0.10947 0.26919 -0.069167 0.27475 -0.90546 0.54632 -0.6847 0.35787 -0.015019 0.42209 -0.06252 -0.33265 -0.60945 -0.23269 -0.40932 0.51566 0.84726 0.020946\n',
#  ', 0.32299 -0.58293 -0.23327 0.34409 -0.56934 1.3211 -0.086267 0.20526 0.5832 0.47516 0.45729 -0.26095 -2.9556 0.16734 0.4654 0.001953 0.31176 -0.49288 -0.49587 -0.28971 0.20519 -0.095402 -0.55419 0.25766 -0.55587 -2.4797 -0.56455 -0.1794 0.4226 -0.32263 -0.3376 0.4137 -0.26111 0.58089 -0.21375 0.1299 -0.010004 -0.14399 -0.18322 -0.30611 -1.4484 0.72222 -0.4705 0.40947 0.16963 -0.14548 0.10416 0.054201 -0.58036 -0.45506 -0.28475 -0.027517 0.10678 -0.10471 -0.067661 -0.16074 -0.34465 -0.14152 0.39862 0.2999 -0.028444 0.38092 -0.18922 -0.03784 0.27486 0.055035 -0.19807 -0.87173 -0.13253 0.39552 0.3629 0.46096 -0.17526 0.31682 -0.24622 -0.71199 0.17775 -0.93663 -0.10047 0.6859 0.54252 -0.072833 -0.19375 0.5751 0.27908 0.3072 0.18803 1.2644 -0.4354 0.49524 -0.51962 -0.62252 0.03495 0.20205 -0.18469 -0.54402 0.2475 -0.93883 -0.082771 -0.22574\n']

# %%
a = [o for o in open("drive/MyDrive/glove.twitter.27B.100d.txt", encoding='utf-8')][110]

# %%
values = a.rstrip().split(' ')

# %%
len(values)
# Out:
# 101

# %%
import numpy as np

def get_coefs(word, *arr):
    return word, np.asarray(arr, dtype=np.float32)

# Path to GloVe file
EMBEDDING_FILE = 'drive/MyDrive/glove.twitter.27B.100d.txt'

def load_embeddings(embedding_file, word_index, max_features):
    embeddings_index = {}

    # Load embeddings safely
    with open(embedding_file, encoding='utf-8') as f:
        for line in f:
            values = line.rstrip().split(' ')
            word = values[0]
            coefs = np.asarray(values[1:], dtype=np.float32)
            embeddings_index[word] = coefs

    # Stack only the vectors (not dict_values directly)
    all_embs = np.stack(list(embeddings_index.values()))
    emb_mean, emb_std = all_embs.mean(), all_embs.std()
    embed_size = all_embs.shape[1]

    # +1 because tokenizer indices start from 1 (0 is padding)
    nb_words = min(max_features, len(word_index) + 1)

    embedding_matrix = np.random.normal(
        emb_mean, emb_std, (nb_words, embed_size)
    ).astype(np.float32)

    # Fill embedding matrix
    for word, i in word_index.items():
        if i >= max_features:
            continue
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector

    return embedding_matrix, embed_size


embedding_matrix, embed_size = load_embeddings(
    EMBEDDING_FILE, tokenizer.word_index, max_features
)

# %%
# def get_coefs(word, *arr):
#     return word, np.asarray(arr, dtype='float32')

# # Step 11: Load pre-trained GloVe embeddings
# EMBEDDING_FILE = 'drive/MyDrive/glove.twitter.27B.100d.txt'

# def load_embeddings(embedding_file, word_index, max_features):
#     embeddings_index = dict(get_coefs(*o.rstrip().rsplit(' ')) for o in open(embedding_file, encoding='utf-8'))
#     all_embs = np.stack(embeddings_index.values())
#     emb_mean, emb_std = all_embs.mean(), all_embs.std()
#     embed_size = all_embs.shape[1]

#     nb_words = min(max_features, len(word_index))
#     embedding_matrix = np.random.normal(emb_mean, emb_std, (nb_words, embed_size))
#     for word, i in word_index.items():
#         if i >= max_features:
#             continue
#         embedding_vector = embeddings_index.get(word)
#         if embedding_vector is not None:
#             embedding_matrix[i] = embedding_vector

#     return embedding_matrix, embed_size

# embedding_matrix, embed_size = load_embeddings(EMBEDDING_FILE, tokenizer.word_index, max_features)

# %% [markdown]
# ## STEP 8: Model definition and training

# %%
embedding_matrix
# Out:
# array([[ 0.03823384, -0.31959686, -1.902671  , ..., -0.25771222,
#          0.42580712, -1.4502771 ],
#        [ 0.64024   ,  0.77112   ,  0.32823   , ..., -0.41058   ,
#          0.53272   , -0.01706   ],
#        [-0.24645   ,  0.45248   ,  0.8372    , ..., -0.98968   ,
#         -0.25141   , -0.54979   ],
#        ...,
#        [ 0.16416   ,  0.035682  , -0.15001   , ..., -0.19446   ,
#         -0.85747   ,  0.24056   ],
#        [ 0.95876   , -0.44844   , -0.24028   , ..., -0.87196   ,
#         -1.1468    ,  0.16303   ],
#        [ 0.19503   , -0.09205   , -0.11285   , ...,  0.40527   ,
#          0.23227   , -0.040952  ]], dtype=float32)

# %%
batch_size = 256
epochs = 3
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=2, verbose=1, factor=0.5, min_lr=0.00001)

model = Sequential()
model.add(Embedding(max_features, output_dim=embed_size, weights=[embedding_matrix], input_length=maxlen, trainable=False))
model.add(LSTM(units=128, return_sequences=True, recurrent_dropout=0.25, dropout=0.25))
model.add(LSTM(units=64, recurrent_dropout=0.1, dropout=0.1))
model.add(Dense(units=32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(x_train, y_train, batch_size=batch_size, validation_data=(x_test, y_test), epochs=epochs, callbacks=[learning_rate_reduction])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/3
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 263s 2s/step - accuracy: 0.8481 - loss: 0.3562 - val_accuracy: 0.9556 - val_loss: 0.1287 - learning_rate: 0.0010
# Epoch 2/3
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 250s 2s/step - accuracy: 0.9425 - loss: 0.1593 - val_accuracy: 0.9659 - val_loss: 0.1072 - learning_rate: 0.0010
# Epoch 3/3
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 250s 2s/step - accuracy: 0.9627 - loss: 0.1103 - val_accuracy: 0.9400 - val_loss: 0.1492 - learning_rate: 0.0010

# %% [markdown]
# ## STEP 9: Model evaluation and analysis

# %%
print("Accuracy on Training Data:", model.evaluate(x_train, y_train)[1] * 100, "%")
print("Accuracy on Testing Data:", model.evaluate(x_test, y_test)[1] * 100, "%")
# Out:
# 1053/1053 ━━━━━━━━━━━━━━━━━━━━ 350s 332ms/step - accuracy: 0.9476 - loss: 0.1356
# Accuracy on Training Data: 94.63962316513062 %
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 115s 327ms/step - accuracy: 0.9391 - loss: 0.1528
# Accuracy on Testing Data: 93.9955472946167 %

# %%
# Get the actual number of epochs from the history object
actual_epochs = len(history.history['accuracy'])

epochs = [i for i in range(actual_epochs)]  # Adjust epochs array based on the actual number of epochs
fig, ax = plt.subplots(1, 2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(20, 10)

ax[0].plot(epochs, train_acc, 'go-', label='Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label='Testing Accuracy')
ax[0].set_title('Training & Testing Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'go-', label='Training Loss')
ax[1].plot(epochs, val_loss, 'ro-', label='Testing Loss')
ax[1].set_title('Training & Testing Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")

plt.show()

# %% [markdown]
# ## Step 10: Confusion Matrix and Classification Report

# %%
# Use predict method to get predicted probabilities
pred_probabilities = model.predict(x_test)

# Threshold predicted probabilities to get predicted classes
pred = (pred_probabilities > 0.5).astype('int32')

print(classification_report(y_test, pred, target_names=['Fake', 'Not Fake']))
cm = confusion_matrix(y_test, pred)
cm = pd.DataFrame(cm, index=['Fake', 'Original'], columns=['Fake', 'Original'])

plt.figure(figsize=(10, 10))
sns.heatmap(cm, cmap="Blues", linecolor='black', linewidth=1, annot=True, fmt='', xticklabels=['Fake', 'Original'], yticklabels=['Fake', 'Original'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 120s 340ms/step
#               precision    recall  f1-score   support
#
#         Fake       0.98      0.91      0.94      5858
#     Not Fake       0.91      0.98      0.94      5367
#
#     accuracy                           0.94     11225
#    macro avg       0.94      0.94      0.94     11225
# weighted avg       0.94      0.94      0.94     11225
